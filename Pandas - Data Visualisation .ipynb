# %%
import pandas as pd
titanic_train = pd.read_csv("C:\\Users\\Utkarsh\\Desktop\\titanic.csv")
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(titanic_train.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
dy = titanic_train.dtypes

# %%
dy["Pclass"]
# Out:
# dtype('int64')

# %%
for i in dy.index:
    print(f"Column named as {i} is of -----> {dy[i]}-----data_type")
# Out:
# Column named as PassengerId is of -----> int64-----data_type
# Column named as Survived is of -----> int64-----data_type
# Column named as Pclass is of -----> int64-----data_type
# Column named as Name is of -----> object-----data_type
# Column named as Sex is of -----> object-----data_type
# Column named as Age is of -----> float64-----data_type
# Column named as SibSp is of -----> int64-----data_type
# Column named as Parch is of -----> int64-----data_type
# Column named as Ticket is of -----> object-----data_type
# Column named as Fare is of -----> float64-----data_type
# Column named as Cabin is of -----> object-----data_type
# Column named as Embarked is of -----> object-----data_type

# %%
dy.values
# Out:
# array([dtype('int64'), dtype('int64'), dtype('int64'), dtype('O'),
#        dtype('O'), dtype('float64'), dtype('int64'), dtype('int64'),
#        dtype('O'), dtype('float64'), dtype('O'), dtype('O')], dtype=object)

# %%
dy.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object>

# %%
dy[0:5]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# Sex            object
# dtype: object

# %%
dy.index[0:43]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dy.values[0:324]
# Out:
# array([dtype('int64'), dtype('int64'), dtype('int64'), dtype('O'),
#        dtype('O'), dtype('float64'), dtype('int64'), dtype('int64'),
#        dtype('O'), dtype('float64'), dtype('O'), dtype('O')], dtype=object)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
titanic_train[["Age"]]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 151  22.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [156 rows x 1 columns]

# %%
type(titanic_train["Age"])
# Out:
# pandas.core.series.Series

# %%
type(titanic_train.iloc[5])
# Out:
# pandas.core.series.Series

# %%
type(titanic_train.iloc[0:10])
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic_train[["Age", "Name", "Sex"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train[["Age", "Name", "Sex"]]
# Out:
#       Age                                               Name     Sex
# 0    22.0                            Braund, Mr. Owen Harris    male
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2    26.0                             Heikkinen, Miss. Laina  female
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4    35.0                           Allen, Mr. William Henry    male
# ..    ...                                                ...     ...
# 151  22.0                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152  55.5                                   Meo, Mr. Alfonzo    male
# 153  40.5                    van Billiard, Mr. Austin Blyler    male
# 154   NaN                              Olsen, Mr. Ole Martin    male
# 155  51.0                        Williams, Mr. Charles Duane    male
#
# [156 rows x 3 columns]

# %%
titanic_train["Age", "Name", "Sex"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Age', 'Name', 'Sex')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic_train["Age"][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
titanic_train[["Age"]][10:100]
# Out:
#      Age
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# ..   ...
# 95   NaN
# 96  71.0
# 97  23.0
# 98  34.0
# 99  34.0
#
# [90 rows x 1 columns]

# %%
titanic_train["Age"][::-1]
# Out:
# 155    51.0
# 154     NaN
# 153    40.5
# 152    55.5
# 151    22.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 156, dtype: float64

# %%
titanic_train["Age"][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6488/3517148772.py in <module>
# ----> 1 titanic_train["Age"][-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
titanic_train.iloc[-1]
# Out:
# PassengerId                            156
# Survived                                 0
# Pclass                                   1
# Name           Williams, Mr. Charles Duane
# Sex                                   male
# Age                                   51.0
# SibSp                                    0
# Parch                                    1
# Ticket                            PC 17597
# Fare                               61.3792
# Cabin                                  NaN
# Embarked                                 C
# Name: 155, dtype: object

# %%
titanic_train.iloc[[-1]]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 155          156         0       1  Williams, Mr. Charles Duane  male  51.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 155      0      1  PC 17597  61.3792   NaN        C

# %%
titanic_train.iloc[[-1]]["Age"]
# Out:
# 155    51.0
# Name: Age, dtype: float64

# %%
titanic_train.iloc[[-1]][["Age"]]
# Out:
#       Age
# 155  51.0

# %%
list(titanic_train["Age"][::])
# Out:
# [22.0,
#  38.0,
#  26.0,
#  35.0,
#  35.0,
#  nan,
#  54.0,
#  2.0,
#  27.0,
#  14.0,
#  4.0,
#  58.0,
#  20.0,
#  39.0,
#  14.0,
#  55.0,
#  2.0,
#  nan,
#  31.0,
#  nan,
#  35.0,
#  34.0,
#  15.0,
#  28.0,
#  8.0,
#  38.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  nan,
#  66.0,
#  28.0,
#  42.0,
#  nan,
#  21.0,
#  18.0,
#  14.0,
#  40.0,
#  27.0,
#  nan,
#  3.0,
#  19.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  18.0,
#  7.0,
#  21.0,
#  49.0,
#  29.0,
#  65.0,
#  nan,
#  21.0,
#  28.5,
#  5.0,
#  11.0,
#  22.0,
#  38.0,
#  45.0,
#  4.0,
#  nan,
#  nan,
#  29.0,
#  19.0,
#  17.0,
#  26.0,
#  32.0,
#  16.0,
#  21.0,
#  26.0,
#  32.0,
#  25.0,
#  nan,
#  nan,
#  0.83,
#  30.0,
#  22.0,
#  29.0,
#  nan,
#  28.0,
#  17.0,
#  33.0,
#  16.0,
#  nan,
#  23.0,
#  24.0,
#  29.0,
#  20.0,
#  46.0,
#  26.0,
#  59.0,
#  nan,
#  71.0,
#  23.0,
#  34.0,
#  34.0,
#  28.0,
#  nan,
#  21.0,
#  33.0,
#  37.0,
#  28.0,
#  21.0,
#  nan,
#  38.0,
#  nan,
#  47.0,
#  14.5,
#  22.0,
#  20.0,
# ...

# %%
titanic_train.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
# our objective is to use the describe function for the columns which are of object datatype

# %%
titanic_train.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(titanic_train.dtypes == "object")
# Out:
# pandas.core.series.Series

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes["Name", "Sex", "Ticket", "Cabin", "Embarked"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6488/2737061896.py in <module>
# ----> 1 titanic_train.dtypes["Name", "Sex", "Ticket", "Cabin", "Embarked"]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     979             )
#     980         elif isinstance(key, tuple):
# --> 981             return self._get_values_tuple(key)
#     982
#     983         elif not is_list_like(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#    1014
#    1015         if not isinstance(self.index, MultiIndex):
# ...

# %%
titanic_train.dtypes[["Name", "Sex", "Ticket", "Cabin", "Embarked"]]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[["Name"]]
# Out:
# Name    object
# dtype: object

# %%
titanic_train.dtypes["Name"]
# Out:
# dtype('O')

# %%
titanic_train[titanic_train.dtypes[titanic_train.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1 = titanic_train[titanic_train.dtypes[titanic_train.dtypes=="object"].index]

# %%
df1.describe()
# Out:
#                            Name   Sex Ticket        Cabin Embarked
# count                       156   156    156           31      155
# unique                      156     2    145           28        3
# top     Braund, Mr. Owen Harris  male   2651  C23 C25 C27        S
# freq                          1   100      2            2      110

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
titanic_train[["Name", "Fare"]]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  66.6000
# 152                                   Meo, Mr. Alfonzo   8.0500
# 153                    van Billiard, Mr. Austin Blyler  14.5000
# 154                              Olsen, Mr. Ole Martin   7.3125
# 155                        Williams, Mr. Charles Duane  61.3792
#
# [156 rows x 2 columns]

# %%
type(titanic_train[["Name", "Fare"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# let us suppose our need is to find out the Passenger IDs from age column having null values

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train["Age"].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train[titanic_train["Age"].isnull() == True][["PassengerId"]]
# Out:
#      PassengerId
# 5              6
# 17            18
# 19            20
# 26            27
# 28            29
# 29            30
# 31            32
# 32            33
# 36            37
# 42            43
# 45            46
# 46            47
# 47            48
# 48            49
# 55            56
# 64            65
# 65            66
# 76            77
# 77            78
# 82            83
# 87            88
# 95            96
# 101          102
# 107          108
# 109          110
# 121          122
# 126          127
# 128          129
# 140          141
# 154          155

# %%
# method 2

# %%
import numpy as np
np.where(titanic_train["Age"].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
l = np.where(titanic_train["Age"].isnull() == True)

# %%
titanic_train.iloc[l]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
titanic_train.iloc[l].PassengerId
# Out:
# 5        6
# 17      18
# 19      20
# 26      27
# 28      29
# 29      30
# 31      32
# 32      33
# 36      37
# 42      43
# 45      46
# 46      47
# 47      48
# 48      49
# 55      56
# 64      65
# 65      66
# 76      77
# 77      78
# 82      83
# 87      88
# 95      96
# 101    102
# 107    108
# 109    110
# 121    122
# 126    127
# 128    129
# 140    141
# 154    155
# Name: PassengerId, dtype: int64

# %%
titanic_train.iloc[l][["PassengerId"]]
# Out:
#      PassengerId
# 5              6
# 17            18
# 19            20
# 26            27
# 28            29
# 29            30
# 31            32
# 32            33
# 36            37
# 42            43
# 45            46
# 46            47
# 47            48
# 48            49
# 55            56
# 64            65
# 65            66
# 76            77
# 77            78
# 82            83
# 87            88
# 95            96
# 101          102
# 107          108
# 109          110
# 121          122
# 126          127
# 128          129
# 140          141
# 154          155

# %%
# extract the name whose fare is maximum

# %%
titanic_train[titanic_train["Fare"]==titanic_train["Fare"].max()][["Name"]]
# Out:
#                               Name
# 27  Fortune, Mr. Charles Alexander
# 88      Fortune, Miss. Mabel Helen

# %%
# method 2

# %%
titanic_train.iloc[np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))][["Name"]]
# Out:
#                               Name
# 27  Fortune, Mr. Charles Alexander
# 88      Fortune, Miss. Mabel Helen

# %%
# let us suppose our requirement is to find out the names of the person having age = 24

# %%
#method 1

titanic_train.iloc[np.where(titanic_train["Age"] == 24)][["Name"]]
# Out:
#                                                   Name
# 89                              Celotti, Mr. Francesco
# 118                           Baxter, Mr. Quigg Edmond
# 127                          Madsen, Mr. Fridtjof Arne
# 139                                 Giglio, Mr. Victor
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...

# %%
#method 2
titanic_train[titanic_train["Age"] == 24][["Name"]]
# Out:
#                                                   Name
# 89                              Celotti, Mr. Francesco
# 118                           Baxter, Mr. Quigg Edmond
# 127                          Madsen, Mr. Fridtjof Arne
# 139                                 Giglio, Mr. Victor
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...

# %%
# name of youngest person

# %%
titanic_train[titanic_train["Age"] == titanic_train["Age"].min()][["Name"]]
# Out:
#                              Name
# 78  Caldwell, Master. Alden Gates

# %%
# Age of persons having cabin value as NaN

# %%
titanic_train.iloc[np.where(titanic_train["Cabin"].isnull() == True)][["Age"]]
# Out:
#       Age
# 0    22.0
# 2    26.0
# 4    35.0
# 5     NaN
# 7     2.0
# ..    ...
# 150  51.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [125 rows x 1 columns]

# %%
# Name of male passengers who survived?

# %%
titanic_train[(titanic_train["Survived"] == 1) & (titanic_train["Sex"] == "male")][["Name"]]
# Out:
#                                              Name
# 17                   Williams, Mr. Charles Eugene
# 21                          Beesley, Mr. Lawrence
# 23                   Sloper, Mr. William Thompson
# 36                               Mamee, Mr. Hanna
# 55                              Woolner, Mr. Hugh
# 65                       Moubarek, Master. Gerios
# 74                                  Bing, Mr. Lee
# 78                  Caldwell, Master. Alden Gates
# 81                    Sheerlinck, Mr. Jan Baptist
# 97                Greenfield, Mr. William Bertram
# 107                        Moss, Mr. Albert Johan
# 125                  Nicola-Yarred, Master. Elias
# 127                     Madsen, Mr. Fridtjof Arne
# 146  Andersson, Mr. August Edvard ("Wennerstrom")

# %%
titanic_train[(titanic_train.Survived == 1) & (titanic_train.Sex == "male")][["Name"]]
# Out:
#                                              Name
# 17                   Williams, Mr. Charles Eugene
# 21                          Beesley, Mr. Lawrence
# 23                   Sloper, Mr. William Thompson
# 36                               Mamee, Mr. Hanna
# 55                              Woolner, Mr. Hugh
# 65                       Moubarek, Master. Gerios
# 74                                  Bing, Mr. Lee
# 78                  Caldwell, Master. Alden Gates
# 81                    Sheerlinck, Mr. Jan Baptist
# 97                Greenfield, Mr. William Bertram
# 107                        Moss, Mr. Albert Johan
# 125                  Nicola-Yarred, Master. Elias
# 127                     Madsen, Mr. Fridtjof Arne
# 146  Andersson, Mr. August Edvard ("Wennerstrom")

# %%
# data manipulation

# %%
titanic_train["new_col"] = "ukc"

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# convert a list into series

l = [23423, 345, 344523, 345, 33, 423456]

# %%
pd.Series(l)
# Out:
# 0     23423
# 1       345
# 2    344523
# 3       345
# 4        33
# 5    423456
# dtype: int64

# %%
type(pd.Series(l))
# Out:
# pandas.core.series.Series

# %%
pd.Series(l).index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
pd.Series(l).values
# Out:
# array([ 23423,    345, 344523,    345,     33, 423456], dtype=int64)

# %%
# convert a diction into series or dataframe

# %%
d = {"name": "ukc", "title":"choubey", "mail_id":"sfghj@gmail.com", "phone":12345678}

# %%
pd.Series(d)
# Out:
# name                   ukc
# title              choubey
# mail_id    sfghj@gmail.com
# phone             12345678
# dtype: object

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6488/2567112034.py in <module>
# ----> 1 pd.DataFrame(d)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
pd.DataFrame(d, index= ["name", "title", "mail_id", "phone"])
# Out:
#         name    title          mail_id     phone
# name     ukc  choubey  sfghj@gmail.com  12345678
# title    ukc  choubey  sfghj@gmail.com  12345678
# mail_id  ukc  choubey  sfghj@gmail.com  12345678
# phone    ukc  choubey  sfghj@gmail.com  12345678

# %%
#convert an array into dataframe

# %%
arr = np.random.randn(3,4)
arr
# Out:
# array([[-1.10404137, -0.63004985,  0.66722199, -0.1594517 ],
#        [-0.887439  ,  0.81198691, -0.16908892, -0.95975746],
#        [ 0.01284336, -0.10073108, -0.90808969,  0.55793774]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -1.104041 -0.630050  0.667222 -0.159452
# 1 -0.887439  0.811987 -0.169089 -0.959757
# 2  0.012843 -0.100731 -0.908090  0.557938

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6488/2396573727.py in <module>
# ----> 1 pd.Series(arr)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ...

# %%
pd.Series(np.array([33,3,234,36,34,42,34]))
# Out:
# 0     33
# 1      3
# 2    234
# 3     36
# 4     34
# 5     42
# 6     34
# dtype: int32

# %%
# how can we give our index
# Trying to differentiate between iloc and loc
pd.Series(np.array([33,3,234,36,34,42,34]), index = ["a","b", "c","d", "e", "f", "g"])
# Out:
# a     33
# b      3
# c    234
# d     36
# e     34
# f     42
# g     34
# dtype: int32

# %%
ser = pd.Series(np.array([33,3,234,36,34,42,34]), index = ["a","b", "c","d", "e", "f", "g"])

# %%
ser["c"]
# Out:
# 234

# %%
ser.iloc[2]
# Out:
# 234

# %%
ser.iloc["c"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6488/1579543178.py in <module>
# ----> 1 ser.iloc["c"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser.loc["c"]
# Out:
# 234

# %%
# Trying to differentiate between iloc and loc more clearly

# %%
pd.Series(np.array([33,3,234,36,34,42,34]), index = [1,2,3,4,5,6,7])
# Out:
# 1     33
# 2      3
# 3    234
# 4     36
# 5     34
# 6     42
# 7     34
# dtype: int32

# %%
ser[2]
# Out:
# 234

# %%
ser.iloc[2]
# Out:
# 234

# %%
ser.loc[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# give own column name and row name

# %%
arr = np.random.randint(56, 100, (4,5))
arr
# Out:
# array([[81, 90, 64, 78, 87],
#        [90, 68, 63, 88, 90],
#        [75, 94, 60, 97, 87],
#        [58, 82, 77, 65, 86]])

# %%
pd.DataFrame(arr)
# Out:
#     0   1   2   3   4
# 0  81  90  64  78  87
# 1  90  68  63  88  90
# 2  75  94  60  97  87
# 3  58  82  77  65  86

# %%
pd.DataFrame(arr, columns=["a", "b", "c", "d", "e"])
# Out:
#     a   b   c   d   e
# 0  81  90  64  78  87
# 1  90  68  63  88  90
# 2  75  94  60  97  87
# 3  58  82  77  65  86

# %%
pd.DataFrame(arr, columns=["col1", "col2", "col3", "col4", "col5"], index= ["record1", "record2", "record3", "record4"])
# Out:
#          col1  col2  col3  col4  col5
# record1    81    90    64    78    87
# record2    90    68    63    88    90
# record3    75    94    60    97    87
# record4    58    82    77    65    86

# %%
df = pd.DataFrame(arr, columns=["col1", "col2", "col3", "col4", "col5"], index= ["record1", "record2", "record3", "record4"])

# %%
df
# Out:
#          col1  col2  col3  col4  col5
# record1    81    90    64    78    87
# record2    90    68    63    88    90
# record3    75    94    60    97    87
# record4    58    82    77    65    86

# %%
df.loc[["record3", "record4"]][["col3", "col4"]]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.loc[["record3", "record4"],["col3", "col4"]]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.loc["record3":,"col3": "col4"]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.loc["record3":"record4","col3": "col4"]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.iloc[[2,3],[2,3]]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.iloc[2:,2:4]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df.iloc[2:4000,2:4]
# Out:
#          col3  col4
# record3    60    97
# record4    77    65

# %%
df
# Out:
#          col1  col2  col3  col4  col5
# record1    81    90    64    78    87
# record2    90    68    63    88    90
# record3    75    94    60    97    87
# record4    58    82    77    65    86

# %%
# add a new column

# %%
df["col6"] = df["col1"] + df["col2"]

# %%
df
# Out:
#          col1  col2  col3  col4  col5  col6
# record1    81    90    64    78    87   171
# record2    90    68    63    88    90   158
# record3    75    94    60    97    87   169
# record4    58    82    77    65    86   140

# %%
# drop one or more column/row

# %%
df.drop("col6", axis = 1)
# Out:
#          col1  col2  col3  col4  col5
# record1    81    90    64    78    87
# record2    90    68    63    88    90
# record3    75    94    60    97    87
# record4    58    82    77    65    86

# %%
df
# Out:
#          col1  col2  col3  col4  col5  col6
# record1    81    90    64    78    87   171
# record2    90    68    63    88    90   158
# record3    75    94    60    97    87   169
# record4    58    82    77    65    86   140

# %%
df1 = df.drop("col6", axis=1)
df1
# Out:
#          col1  col2  col3  col4  col5
# record1    81    90    64    78    87
# record2    90    68    63    88    90
# record3    75    94    60    97    87
# record4    58    82    77    65    86

# %%
df2 = df.drop("record4")

# %%
df2
# Out:
#          col1  col2  col3  col4  col5  col6
# record1    81    90    64    78    87   171
# record2    90    68    63    88    90   158
# record3    75    94    60    97    87   169

# %%
df
# Out:
#          col1  col2  col3  col4  col5  col6
# record1    81    90    64    78    87   171
# record2    90    68    63    88    90   158
# record3    75    94    60    97    87   169
# record4    58    82    77    65    86   140

# %%
df3 = df.drop(["col1", "col2"], axis = 1)

# %%
df3
# Out:
#          col3  col4  col5  col6
# record1    64    78    87   171
# record2    63    88    90   158
# record3    60    97    87   169
# record4    77    65    86   140

# %%
df
# Out:
#          col1  col2  col3  col4  col5  col6
# record1    81    90    64    78    87   171
# record2    90    68    63    88    90   158
# record3    75    94    60    97    87   169
# record4    58    82    77    65    86   140

# %%
# let us suppose we want to have negative values

# %%
np.random.seed(23)
arr = np.random.randn(4,5)
df = pd.DataFrame(arr,columns=["col1", "col2", "col3", "col4", "col5"], index= ["record1", "record2", "record3", "record4"])
df
# Out:
#              col1      col2      col3      col4      col5
# record1  0.666988  0.025813 -0.777619  0.948634  0.701672
# record2 -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# record3 -0.347459  0.670140  0.322272  0.060343 -1.043450
# record4 -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[np.where(df.values<0)]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
# let us suppose we want to have negative values 
# along with their respective col and row names

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i]<0:
            print(f"{i}, {j} ------> {df.loc[j,i]}")
# Out:
# col1, record2 ------> -1.0510815639071178
# col1, record3 ------> -0.34745899102186334
# col1, record4 ------> -1.0099418765878465
# col2, record2 ------> -0.3675481161171661
# col3, record1 ------> -0.7776194131918178
# col3, record2 ------> -1.1374596907250272
# col4, record2 ------> -1.3221475225908594
# col4, record4 ------> -1.8380677677579502
# col5, record3 ------> -1.0434500017467254
# col5, record4 ------> -0.9387686311201282

# %%
# drop reords/columns

# %%
d = {"key1": [1,2,3,4,np.nan], "key2": ["ukc", "kumar", 4,5,6], "key3": [np.nan, np.nan, np.nan, 3,8]}
df = pd.DataFrame(d)
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1)
# Out:
#     key2
# 0    ukc
# 1  kumar
# 2      4
# 3      5
# 4      6

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
# threshold meaning

# %%
d = {"key1": [1,2,3,4,np.nan], "key2": ["ukc", "kumar", np.nan,5,6], "key3": [np.nan, np.nan, np.nan, 3,8]}
df = pd.DataFrame(d)
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
# fillna

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna(567)
# Out:
#     key1   key2   key3
# 0    1.0    ukc  567.0
# 1    2.0  kumar  567.0
# 2    3.0    567  567.0
# 3    4.0      5    3.0
# 4  567.0      6    8.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0    ukc   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
 df.fillna(value=df["key1"].mean())
# Out:
#    key1   key2  key3
# 0   1.0    ukc   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
# groupby

# %%
d1 = {"name":["Anshu","Sanju","Ukc", "Lucky", "Raju"], "mail_id":["anshu@gmail.com", "Sanju@gmail.com", "Sanju@gmail.com", "Lucky@gmail.com", "anshu@gmail.com"], "Salary":[500,200,400,700,300]}
df = pd.DataFrame(d1)
df
# Out:
#     name          mail_id  Salary
# 0  Anshu  anshu@gmail.com     500
# 1  Sanju  Sanju@gmail.com     200
# 2    Ukc  Sanju@gmail.com     400
# 3  Lucky  Lucky@gmail.com     700
# 4   Raju  anshu@gmail.com     300

# %%
df.groupby("name").mean()
# Out:
#        Salary
# name
# Anshu   500.0
# Lucky   700.0
# Raju    300.0
# Sanju   200.0
# Ukc     400.0

# %%
df.groupby("mail_id").mean()
# Out:
#                  Salary
# mail_id
# Lucky@gmail.com   700.0
# Sanju@gmail.com   300.0
# anshu@gmail.com   400.0

# %%
df.groupby("mail_id").describe()
# Out:
#                 Salary
#                  count   mean         std    min    25%    50%    75%    max
# mail_id
# Lucky@gmail.com    1.0  700.0         NaN  700.0  700.0  700.0  700.0  700.0
# Sanju@gmail.com    2.0  300.0  141.421356  200.0  250.0  300.0  350.0  400.0
# anshu@gmail.com    2.0  400.0  141.421356  300.0  350.0  400.0  450.0  500.0

# %%
# transpose

# %%
df.T
# Out:
#                        0                1                2                3  \
# name               Anshu            Sanju              Ukc            Lucky
# mail_id  anshu@gmail.com  Sanju@gmail.com  Sanju@gmail.com  Lucky@gmail.com
# Salary               500              200              400              700
#
#                        4
# name                Raju
# mail_id  anshu@gmail.com
# Salary               300

# %%
df.transpose()
# Out:
#                        0                1                2                3  \
# name               Anshu            Sanju              Ukc            Lucky
# mail_id  anshu@gmail.com  Sanju@gmail.com  Sanju@gmail.com  Lucky@gmail.com
# Salary               500              200              400              700
#
#                        4
# name                Raju
# mail_id  anshu@gmail.com
# Salary               300

# %%
# concatenation (vertical/horizontal) of different dataframes

# %%
np.random.seed(25)
arr1 =  np.random.randn(3,4)
np.random.seed(26)
arr2 =  np.random.randn(3,4)
np.random.seed(27)
arr3 =  np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1, columns= ["A","B","C","D"])

# %%
df2 = pd.DataFrame(arr2, columns= ["A","B","C","D"])

# %%
df3 = pd.DataFrame(arr3, columns= ["A","B","C","D"])

# %%
df1
# Out:
#           A         B         C         D
# 0  0.228273  1.026890 -0.839585 -0.591182
# 1 -0.956888 -0.222326 -0.619915  1.837905
# 2 -2.053231  0.868583 -0.920734 -0.232312

# %%
df2
# Out:
#           A         B         C         D
# 0  0.195993 -1.941236  0.713785  0.662148
# 1 -0.228862  0.271751 -0.029069 -1.759582
# 2 -0.794281  0.622622  0.159340 -1.314304

# %%
df3
# Out:
#           A         B         C         D
# 0  1.285605 -0.303553  0.619076  0.395999
# 1  0.223406 -0.054339 -0.179276  0.242832
# 2  0.821057  1.217054  0.559449  0.376743

# %%
#rowwise concatenation
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0  0.228273  1.026890 -0.839585 -0.591182
# 1 -0.956888 -0.222326 -0.619915  1.837905
# 2 -2.053231  0.868583 -0.920734 -0.232312
# 0  0.195993 -1.941236  0.713785  0.662148
# 1 -0.228862  0.271751 -0.029069 -1.759582
# 2 -0.794281  0.622622  0.159340 -1.314304
# 0  1.285605 -0.303553  0.619076  0.395999
# 1  0.223406 -0.054339 -0.179276  0.242832
# 2  0.821057  1.217054  0.559449  0.376743

# %%
df4 = pd.concat([df1,df2,df3])

# %%
#column_wise concatenation
pd.concat([df1,df2,df3], axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.228273  1.026890 -0.839585 -0.591182  0.195993 -1.941236  0.713785
# 1 -0.956888 -0.222326 -0.619915  1.837905 -0.228862  0.271751 -0.029069
# 2 -2.053231  0.868583 -0.920734 -0.232312 -0.794281  0.622622  0.159340
#
#           D         A         B         C         D
# 0  0.662148  1.285605 -0.303553  0.619076  0.395999
# 1 -1.759582  0.223406 -0.054339 -0.179276  0.242832
# 2 -1.314304  0.821057  1.217054  0.559449  0.376743

# %%
df4
# Out:
#           A         B         C         D
# 0  0.228273  1.026890 -0.839585 -0.591182
# 1 -0.956888 -0.222326 -0.619915  1.837905
# 2 -2.053231  0.868583 -0.920734 -0.232312
# 0  0.195993 -1.941236  0.713785  0.662148
# 1 -0.228862  0.271751 -0.029069 -1.759582
# 2 -0.794281  0.622622  0.159340 -1.314304
# 0  1.285605 -0.303553  0.619076  0.395999
# 1  0.223406 -0.054339 -0.179276  0.242832
# 2  0.821057  1.217054  0.559449  0.376743

# %%
df4.iloc[[0]]
# Out:
#           A        B         C         D
# 0  0.228273  1.02689 -0.839585 -0.591182

# %%
df4.loc[[0]]
# Out:
#           A         B         C         D
# 0  0.228273  1.026890 -0.839585 -0.591182
# 0  0.195993 -1.941236  0.713785  0.662148
# 0  1.285605 -0.303553  0.619076  0.395999

# %%
df5 = pd.concat([df1,df2,df3], axis=1)

# %%
df5["A"] #but we have to extract only 2nd A
# Out:
#           A         A         A
# 0  0.228273  0.195993  1.285605
# 1 -0.956888 -0.228862  0.223406
# 2 -2.053231 -0.794281  0.821057

# %%
df5.iloc[:,4]
# Out:
# 0    0.195993
# 1   -0.228862
# 2   -0.794281
# Name: A, dtype: float64

# %%
df5.iloc[:,[4]]
# Out:
#           A
# 0  0.195993
# 1 -0.228862
# 2 -0.794281

# %%
df1 = pd.DataFrame(arr1, columns= ["A","B","C","D"], index = [0,1,2])

# %%
df2 = pd.DataFrame(arr1, columns= ["A","B","C","D"], index = [3,4,5])

# %%
df3 = pd.DataFrame(arr1, columns= ["A","B","C","D"], index = [6,7,8])

# %%
df4 = pd.concat([df1,df2,df3], axis=1)

# %%
df4
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.228273  1.026890 -0.839585 -0.591182       NaN       NaN       NaN
# 1 -0.956888 -0.222326 -0.619915  1.837905       NaN       NaN       NaN
# 2 -2.053231  0.868583 -0.920734 -0.232312       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.228273  1.026890 -0.839585
# 4       NaN       NaN       NaN       NaN -0.956888 -0.222326 -0.619915
# 5       NaN       NaN       NaN       NaN -2.053231  0.868583 -0.920734
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df4.fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.228273  1.026890 -0.839585 -0.591182  0.000000  0.000000  0.000000
# 1 -0.956888 -0.222326 -0.619915  1.837905  0.000000  0.000000  0.000000
# 2 -2.053231  0.868583 -0.920734 -0.232312  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.228273  1.026890 -0.839585
# 4  0.000000  0.000000  0.000000  0.000000 -0.956888 -0.222326 -0.619915
# 5  0.000000  0.000000  0.000000  0.000000 -2.053231  0.868583 -0.920734
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
# join operations

# %%
left = pd.DataFrame({"key": ["k0", "k8", "k2", "k3"],
                     "A": ["a0", "a1", "a2", "a3"],
                     "B": ["b0", "b1", "b2", "b3"]
                    })

right = pd.DataFrame({"key": ["k0", "k1", "k2", "k3"],
                      "C": ["c0", "c1", "c2", "c3"],
                      "D": ["d0", "d1", "d2", "d3"]
                    })

# %%
left
# Out:
#   key   A   B
# 0  k0  a0  b0
# 1  k8  a1  b1
# 2  k2  a2  b2
# 3  k3  a3  b3

# %%
right
# Out:
#   key   C   D
# 0  k0  c0  d0
# 1  k1  c1  d1
# 2  k2  c2  d2
# 3  k3  c3  d3

# %%
pd.merge(left, right, on="key")
# Out:
#   key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k2  a2  b2  c2  d2
# 2  k3  a3  b3  c3  d3

# %%
pd.merge(left, right, on="key", how= "inner")
# Out:
#   key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k2  a2  b2  c2  d2
# 2  k3  a3  b3  c3  d3

# %%
pd.merge(left, right, on="key", how= "left")
# Out:
#   key   A   B    C    D
# 0  k0  a0  b0   c0   d0
# 1  k8  a1  b1  NaN  NaN
# 2  k2  a2  b2   c2   d2
# 3  k3  a3  b3   c3   d3

# %%
pd.merge(left, right, on="key", how= "right")
# Out:
#   key    A    B   C   D
# 0  k0   a0   b0  c0  d0
# 1  k1  NaN  NaN  c1  d1
# 2  k2   a2   b2  c2  d2
# 3  k3   a3   b3  c3  d3

# %%
pd.merge(left, right, on="key", how= "outer")
# Out:
#   key    A    B    C    D
# 0  k0   a0   b0   c0   d0
# 1  k8   a1   b1  NaN  NaN
# 2  k2   a2   b2   c2   d2
# 3  k3   a3   b3   c3   d3
# 4  k1  NaN  NaN   c1   d1

# %%
left = pd.DataFrame({"key1": ["k0", "k0", "k1", "k2"],
                     "key2": ["k0", "k1", "k0", "k1"],
                     "A": ["a0", "a1", "a2", "a3"],
                     "B": ["b0", "b1", "b2", "b3"]
                    })

right = pd.DataFrame({"key1": ["k0", "k1", "k1", "k2"],
                      "key2": ["k0", "k0", "k0", "k0"],
                      "C": ["c0", "c1", "c2", "c3"],
                      "D": ["d0", "d1", "d2", "d3"]
                    })

# %%
left
# Out:
#   key1 key2   A   B
# 0   k0   k0  a0  b0
# 1   k0   k1  a1  b1
# 2   k1   k0  a2  b2
# 3   k2   k1  a3  b3

# %%
right
# Out:
#   key1 key2   C   D
# 0   k0   k0  c0  d0
# 1   k1   k0  c1  d1
# 2   k1   k0  c2  d2
# 3   k2   k0  c3  d3

# %%
pd.merge(left, right, on=["key1", "key2"])
# Out:
#   key1 key2   A   B   C   D
# 0   k0   k0  a0  b0  c0  d0
# 1   k1   k0  a2  b2  c1  d1
# 2   k1   k0  a2  b2  c2  d2

# %%
# join

# %%
df1 = pd.DataFrame({
                     "A": ["a0", "a1", "a2"],
                     "B": ["b0", "b1", "b2"]},
                     index = ["k0", "k1", "k2"]
                    )

df2 = pd.DataFrame({
                      "C": ["c0", "c2", "c3"],
                      "D": ["d0", "d2", "d3"]},
                      index = ["k0", "k2", "k3"]
                    )

# %%
df1
# Out:
#      A   B
# k0  a0  b0
# k1  a1  b1
# k2  a2  b2

# %%
df2
# Out:
#      C   D
# k0  c0  d0
# k2  c2  d2
# k3  c3  d3

# %%
df1.join(df2) # default join is LEFT JOIN
# Out:
#      A   B    C    D
# k0  a0  b0   c0   d0
# k1  a1  b1  NaN  NaN
# k2  a2  b2   c2   d2

# %%
df1.join(df2, how="right")
# Out:
#       A    B   C   D
# k0   a0   b0  c0  d0
# k2   a2   b2  c2  d2
# k3  NaN  NaN  c3  d3

# %%
df1.join(df2, how="inner")
# Out:
#      A   B   C   D
# k0  a0  b0  c0  d0
# k2  a2  b2  c2  d2

# %%
df1.join(df2, how="outer")
# Out:
#       A    B    C    D
# k0   a0   b0   c0   d0
# k1   a1   b1  NaN  NaN
# k2   a2   b2   c2   d2
# k3  NaN  NaN   c3   d3
